# %%
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt

# %%
from datetime import datetime
from matplotlib import pyplot
from matplotlib.animation import FuncAnimation
from random import randrange

x_data, y_data = [], []

figure = pyplot.figure()
line, = pyplot.plot_date(x_data, y_data, '-')

def update(frame):
    x_data.append(datetime.now())
    y_data.append(randrange(0, 100))
    line.set_data(x_data, y_data)
    figure.gca().relim()
    figure.gca().autoscale_view()
    return line,

animation = FuncAnimation(figure, update, interval=200)

pyplot.show()

# %%
R0=np.random.uniform(0,4)
x0=0.001

# %%
import time
import psutil
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111)
R0=4
x0=0.9
i = 0
x, y = [], []
niter=300
while i<niter:
    x.append(i)
    y.append(x0)
    x0=R0*x0*(1-x0)
    ax.plot(x, y, color='b')
    ax.axhline(2/3,0,i)
    fig.canvas.draw()
    ax.set_xlim(left=max(0, i - niter), right=min(i + 25, niter))
    fig.show()
    plt.pause(0.001)
    i += 1
# Out:
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">

# %%
np.mean(y)
# Out:
# 0.5142692518572787

# %%
R0=4
x0=0.9
check=0.1
niter=300
while check!=0.0:
    x0=R0*x0*(1-x0)
    if x0<check:
        print(x0)
        check=x0
# Out:
# 0.0002463047816241282
# 0.00022638832979198384
# 4.957872601552988e-05
# 8.773152807144234e-06
# 1.6836284421098103e-06
# 8.068239421184873e-07
# 1.3427238387156022e-08
# 1.23140742009758e-09
# 9.275020749280734e-10
# 4.544409292800384e-10
# 3.476818832806905e-11
# 2.485833761041262e-11
# 2.2219559525514605e-11
# 8.089084957402533e-12
# 4.102496120590671e-12
# 2.7227109455888804e-12
# 2.697841949837311e-12
# 1.0542677841837708e-12
# 2.2515322939396907e-13
# 9.68114477473113e-14
# 3.508304757815464e-14
# 7.105427357600989e-15
# 2.664535259100374e-15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-81-d20f05943376> in <module>
#       4 niter=300
#       5 while check!=0.0:
# ----> 6     x0=R0*x0*(1-x0)
#       7     if x0<check:
#       8         print(x0)
#
# KeyboardInterrupt:

# %%
R0=4
x0=0.9+1e-6
check=0.1
niter=300
while check!=0.0:
    x0=R0*x0*(1-x0)
    if x0<check:
        print(x0)
        check=x0
# Out:
# 0.0008610641986135669
# 0.0006946100221450627
# 0.00026375499014269526
# 0.00016947780139981008
# 0.00013419206291276098
# 4.5370063489256374e-07
# 1.538020789319519e-07
# 1.1366542184222748e-07
# 4.708486484048307e-09
# 4.657521918266828e-09
# 3.613969120695976e-09
# 2.983479683300193e-09
# 2.0512924692079048e-11
# 2.5730528818696076e-12
# 1.5543122344752132e-14
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-82-8100c251debc> in <module>
#       4 niter=300
#       5 while check!=0.0:
# ----> 6     x0=R0*x0*(1-x0)
#       7     if x0<check:
#       8         print(x0)
#
# KeyboardInterrupt:
