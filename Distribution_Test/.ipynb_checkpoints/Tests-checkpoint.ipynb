# %%
import numpy as np
from astropy.io import fits
from scipy.stats import gamma
import pandas
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams.update({'font.size': 20})
plt.rc('font', family='serif')
plt.rc('text', usetex=True)

# %%
x=np.linspace(0,10,1000)
gamma.pdf(x, 1)
mean=np.arange(4)
var=np.arange(4)
t=var/mean
k=mean**2/var
rv=gamma(k, scale=t)
fig, ax = plt.subplots(nrows=4,ncols=4, figsize=(15,12))
for i in range(4):
    for j in range(4):
        ax[i][j].plot(x,rv.pdf(x))
# Out:
# C:\Users\chris\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in true_divide
#   """
# C:\Users\chris\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in true_divide
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-e4e915769a02> in <module>
#       9 for i in range(4):
#      10     for j in range(4):
# ---> 11         ax[i][j].plot(x,rv.pdf(x))
#
# ~\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py in pdf(self, x)
#     434
#     435     def pdf(self, x):   # raises AttributeError in frozen discrete distribution
# --> 436         return self.dist.pdf(x, *self.args, **self.kwds)
#     437
#     438     def logpdf(self, x):
#
# ~\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py in pdf(self, x, *args, **kwds)
#    1758         args = tuple(map(asarray, args))
#    1759         dtyp = np.find_common_type([x.dtype, np.float64], [])
# -> 1760         x = np.asarray((x - loc)/scale, dtype=dtyp)
#    1761         cond0 = self._argcheck(*args) & (scale > 0)
#    1762         cond1 = self._support_mask(x, *args) & (scale > 0)
#
# ValueError: operands could not be broadcast together with shapes (1000,) (4,)

# %%
rv.pdf(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-f512679086cf> in <module>
# ----> 1 rv.pdf(x)
#
# ~\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py in pdf(self, x)
#     434
#     435     def pdf(self, x):   # raises AttributeError in frozen discrete distribution
# --> 436         return self.dist.pdf(x, *self.args, **self.kwds)
#     437
#     438     def logpdf(self, x):
#
# ~\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py in pdf(self, x, *args, **kwds)
#    1758         args = tuple(map(asarray, args))
#    1759         dtyp = np.find_common_type([x.dtype, np.float64], [])
# -> 1760         x = np.asarray((x - loc)/scale, dtype=dtyp)
#    1761         cond0 = self._argcheck(*args) & (scale > 0)
#    1762         cond1 = self._support_mask(x, *args) & (scale > 0)
#
# ValueError: operands could not be broadcast together with shapes (1000,) (4,)
